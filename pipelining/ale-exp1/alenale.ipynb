# %%
# %load_ext autoreload
# %autoreload 2

sys.path.insert(1, '../../')
import numpy as np, sys, os, pandas as pd, json
from getting_data import load_sample
from ranker_helper import get_scores

sample_name = 'cslg-rand-1000'

x = load_sample('pdp-exp1', sample_name)

def predictor(df):
    papers = json.loads(df.to_json(orient='records'))
    return get_scores('Machine Learning', papers)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from alepython import ale_plot
# Plots ALE of feature 'cont' with Monte-Carlo replicas (default : 50).
ale_plot(None, x, ['year', 'n_citations'], bins=5, monte_carlo=True, predictor=predictor)
# Out:
# fail to not force global because 1 worker available
# get ranker in 7234 with global setting: True and gb_ranker len 1
# [Main taks:0] compute 1000 scores with worker 7234
# [Main taks][03/06/2022, 16:16:46] 1000 scores within 1.149022 sec
# fail to not force global because 1 worker available
# get ranker in 7234 with global setting: True and gb_ranker len 1
# [Main taks:0] compute 1000 scores with worker 7234
# [Main taks][03/06/2022, 16:16:46] 1000 scores within 0.725409 sec
# fail to not force global because 1 worker available
# get ranker in 7234 with global setting: True and gb_ranker len 1
# [Main taks:0] compute 1000 scores with worker 7234
# [Main taks][03/06/2022, 16:16:47] 1000 scores within 0.722947 sec
# fail to not force global because 1 worker available
# get ranker in 7234 with global setting: True and gb_ranker len 1
# [Main taks:0] compute 1000 scores with worker 7234
# [Main taks][03/06/2022, 16:16:48] 1000 scores within 0.722994 sec
# (5, 5)
# (4, 4)
# ...
